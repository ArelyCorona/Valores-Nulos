# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('listings.csv')

df.head(5)
# Out:
#          id                          listing_url  host_id  host_since  \
# 0   97945.0   https://www.airbnb.com/rooms/97945   517685  18/04/2011
# 1  114695.0  https://www.airbnb.com/rooms/114695   581737  12/05/2011
# 2  127383.0  https://www.airbnb.com/rooms/127383   630556  26/05/2011
# 3  159634.0  https://www.airbnb.com/rooms/159634   765694  01/07/2011
# 4  170154.0  https://www.airbnb.com/rooms/170154   108297  14/04/2010
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                   6%
# 1      within an hour               100%                  99%
# 2      within an hour               100%                  92%
# 3      within an hour               100%                  78%
# 4  within a few hours               100%                 100%
#
#   host_is_superhost  host_listings_count  host_total_listings_count  ...  \
# 0                 f                    2                          3  ...
# ...

# %%
#ELIMINA COLUMNAS INNECESARIAS
#axis = 1 para columnas
#elimine columnas que no aportan valor analítico al análisis, 
# como identificadores únicos o enlaces que no son útiles para el procesamiento de datos
df2 = df.drop(['id','listing_url','host_is_superhost',], axis =1)
df2.head(5)
# Out:
#    host_id  host_since  host_response_time host_response_rate  \
# 0   517685  18/04/2011  a few days or more                 0%
# 1   581737  12/05/2011      within an hour               100%
# 2   630556  26/05/2011      within an hour               100%
# 3   765694  01/07/2011      within an hour               100%
# 4   108297  14/04/2010  within a few hours               100%
#
#   host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 0                   6%                    2                          3
# 1                  99%                    3                          3
# 2                  92%                    2                          2
# 3                  78%                    1                          1
# 4                 100%                    1                          1
#
#                  host_verifications neighbourhood_cleansed  latitude  ...  \
# 0                ['email', 'phone']                 Hadern  48.11492  ...
# ...

# %%
#IDENTIFICAR VALORES NULOS POR COLUMNA
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# host_id                                            0
# host_since                                         0
# host_response_time                              2168
# host_response_rate                              2168
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       2202
# bathrooms_text                                    11
# bedrooms                                         715
# beds                                            2201
# ...

# %%
#IDENTIFICAR VALORES NULOS POR DATAFRAME
valores_nulos=df2.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(34269)

# %%
df3=df2.copy()

# %%
#SUSTITUIR VALORES NULOS CON PROMEDIO O MEDIA
#la columna "bedrooms" la reemplace por el promedio de los valores no nulos
df3["bedrooms"]=df3["bedrooms"].fillna(round(df2["bedrooms"].mean(),1))

# %%
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# host_id                                            0
# host_since                                         0
# host_response_time                              2168
# host_response_rate                              2168
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       2202
# bathrooms_text                                    11
# bedrooms                                           0
# beds                                            2201
# ...

# %%
#Aquí los valores nulos los reemplace con la mediana. 
df3["reviews_per_month"]=df3["reviews_per_month"].fillna(round(df2["reviews_per_month"].median(),1))

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# host_id                                            0
# host_since                                         0
# host_response_time                              2168
# host_response_rate                              2168
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       2202
# bathrooms_text                                    11
# bedrooms                                           0
# beds                                            2201
# ...

# %%
#TERCER MÉTODO DE SUSTITUCIÓN
#SUSTITUIR VALORES NULOS POR UN VALOR NÚMERICO EN CONCRETO - SE UNA 
#Los valores nulos de la columna "bathrooms" los reemplazacep
# or un valor numérico fijo (en este caso, 2)

df3["bathrooms"]=df3["bathrooms"].fillna(2)

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# host_id                                            0
# host_since                                         0
# host_response_time                              2168
# host_response_rate                              2168
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                          0
# bathrooms_text                                    11
# bedrooms                                           0
# beds                                            2201
# ...

# %%
#CUARTO MÉTODO DE SUSUTITUCIÓN
#SUSTITUIR VALORES NULOS POR UN STRING EN CONCRETO
# los valores nulos los reemplace con un string específico ("100%")

df3["host_response_rate"]=df3["host_response_rate"].fillna("100%")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# host_id                                            0
# host_since                                         0
# host_response_time                              2168
# host_response_rate                                 0
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                          0
# bathrooms_text                                    11
# bedrooms                                           0
# beds                                            2201
# ...

# %%
#SUSTITUIR VALORES NULOS POR VALORES NO NULOS HACIA ADELANTE "forward fill"
#FILTRO POR COLUMNAS
#Reemplace los valores nulos con el último valor válido encontrado antes de ellos
df3["beds"]=df3["beds"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18256\834471969.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["beds"]=df3["beds"].fillna(method="ffill")
# host_id                                            0
# host_since                                         0
# host_response_time                              2168
# host_response_rate                                 0
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# ...

# %%
#SUSTITUIR VALORES NULOS POR VALORES NO NULOS HACIA ADELANTE "backward fill"
#FILTRO POR COLUMNAS
#Reemplace los valores nulos con el último valor válido encontrado despues de ellos
df3["host_response_time"]=df3["host_response_time"].fillna(method="bfill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18256\3421952572.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["host_response_time"]=df3["host_response_time"].fillna(method="bfill")
# host_id                                            0
# host_since                                         0
# host_response_time                                 8
# host_response_rate                                 0
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# ...

# %%
df3["bathrooms_text"]=df3["bathrooms_text"].fillna(method="bfill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18256\2840129438.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["bathrooms_text"]=df3["bathrooms_text"].fillna(method="bfill")
# host_id                                            0
# host_since                                         0
# host_response_time                                 8
# host_response_rate                                 0
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# ...

# %%
df3["host_acceptance_rate"]=df3["host_acceptance_rate"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18256\2527316573.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["host_acceptance_rate"]=df3["host_acceptance_rate"].fillna(method="ffill")
# host_id                                            0
# host_since                                         0
# host_response_time                                 8
# host_response_rate                                 0
# host_acceptance_rate                               0
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# ...

# %%
df3["price"]=df3["price"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18256\1071845424.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["price"]=df3["price"].fillna(method="ffill")
# host_id                                            0
# host_since                                         0
# host_response_time                                 8
# host_response_rate                                 0
# host_acceptance_rate                               0
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# ...

# %%
df3["has_availability"]=df3["has_availability"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18256\207084489.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["has_availability"]=df3["has_availability"].fillna(method="ffill")
# host_id                                            0
# host_since                                         0
# host_response_time                                 8
# host_response_rate                                 0
# host_acceptance_rate                               0
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# ...

# %%
df3["host_response_time"]=df3["host_response_time"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18256\3858237801.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["host_response_time"]=df3["host_response_time"].fillna(method="ffill")
# host_id                                            0
# host_since                                         0
# host_response_time                                 0
# host_response_rate                                 0
# host_acceptance_rate                               0
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# ...

# %%
#IDENTIFICAR VALORES NULOS POR COLUMNA
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# host_id                                            0
# host_since                                         0
# host_response_time                              2168
# host_response_rate                              2168
# host_acceptance_rate                            1590
# host_listings_count                                0
# host_total_listings_count                          0
# host_verifications                                 0
# neighbourhood_cleansed                             0
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                       2202
# bathrooms_text                                    11
# bedrooms                                         715
# beds                                            2201
# ...

# %%
#Copia de dataframe
df4=df2.copy()
df4
# Out:
#         host_id  host_since  host_response_time host_response_rate  \
# 0        517685  18/04/2011  a few days or more                 0%
# 1        581737  12/05/2011      within an hour               100%
# 2        630556  26/05/2011      within an hour               100%
# 3        765694  01/07/2011      within an hour               100%
# 4        108297  14/04/2010  within a few hours               100%
# ...         ...         ...                 ...                ...
# 8016    7303138  05/07/2013                 NaN                NaN
# 8017  653646116  23/09/2024                 NaN                NaN
# 8018  653647934  23/09/2024                 NaN                NaN
# 8019  169681505  24/01/2018                 NaN                NaN
# 8020  555221420  08/01/2024                 NaN                NaN
#
#      host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 0                      6%                    2                          3
# ...

# %%
df4=df2.dropna()
df4
# Out:
#         host_id  host_since  host_response_time host_response_rate  \
# 0        517685  18/04/2011  a few days or more                 0%
# 1        581737  12/05/2011      within an hour               100%
# 3        765694  01/07/2011      within an hour               100%
# 4        108297  14/04/2010  within a few hours               100%
# 6        825767  16/07/2011      within an hour               100%
# ...         ...         ...                 ...                ...
# 7729  574407990  26/04/2024  within a few hours               100%
# 7738  593735601  02/08/2024  within a few hours               100%
# 7750   29290604  13/03/2015      within an hour               100%
# 7773   25340776  29/12/2014        within a day               100%
# 7777   69783120  01/05/2016      within an hour               100%
#
#      host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 0                      6%                    2                          3
# ...

# %%
valores_nulos=df4.isnull().sum()
valores_nulos
# Out:
# host_id                                         0
# host_since                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# neighbourhood_cleansed                          0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms                                       0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# amenities                                       0
# ...

# %%
#DATAFRAME (SUSUSTITUCIÓN)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8021 entries, 0 to 8020
# Data columns (total 47 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_id                                       8021 non-null   int64
#  1   host_since                                    8021 non-null   object
#  2   host_response_time                            8021 non-null   object
#  3   host_response_rate                            8021 non-null   object
#  4   host_acceptance_rate                          8021 non-null   object
#  5   host_listings_count                           8021 non-null   int64
#  6   host_total_listings_count                     8021 non-null   int64
#  7   host_verifications                            8021 non-null   object
#  8   neighbourhood_cleansed                        8021 non-null   object
# ...

# %%
#DATAFRAME4 ELIMINACIÓN
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3858 entries, 0 to 7777
# Data columns (total 47 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_id                                       3858 non-null   int64
#  1   host_since                                    3858 non-null   object
#  2   host_response_time                            3858 non-null   object
#  3   host_response_rate                            3858 non-null   object
#  4   host_acceptance_rate                          3858 non-null   object
#  5   host_listings_count                           3858 non-null   int64
#  6   host_total_listings_count                     3858 non-null   int64
#  7   host_verifications                            3858 non-null   object
#  8   neighbourhood_cleansed                        3858 non-null   object
# ...

# %%
#CONVERTIR DATASET SIN VALORES NULOS A CSV
df4.to_csv("listings_sin_nulos.csv")
