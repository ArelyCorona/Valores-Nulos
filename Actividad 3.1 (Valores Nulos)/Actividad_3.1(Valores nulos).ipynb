# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Ventas_totales.csv')

df.head(5)
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0    01/01/2017                    27858.9                    27477.3
# 1    01/02/2017                    25994.2                    25223.4
# 2    01/03/2017                    27780.0                    26334.3
# 3    01/04/2017                    29134.3                    27045.9
# 4    01/05/2017                    27969.0                    25631.9
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 27858872.08   27591730.13       267141.956
# 1                 25994200.17   25749179.40       245020.769
# 2                 27780006.52   27472228.72       307777.804
# 3                 29134272.22   28827479.49       306792.733
# 4                 27969004.68   27569311.41       399693.262
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 0                27858872.08  1.023010e+07      6864575.384       9047205.493
# ...

# %%
#ELIMINA COLUMNAS INNECESARIAS
#axis = 1 para columnas
#axis = 0 para filas
df2 = df.drop(['indice_tiempo'], axis =1)
df2.head(5)
# Out:
#    ventas_precios_corrientes  ventas_precios_constantes  \
# 0                    27858.9                    27477.3
# 1                    25994.2                    25223.4
# 2                    27780.0                    26334.3
# 3                    29134.3                    27045.9
# 4                    27969.0                    25631.9
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 27858872.08   27591730.13       267141.956
# 1                 25994200.17   25749179.40       245020.769
# 2                 27780006.52   27472228.72       307777.804
# 3                 29134272.22   28827479.49       306792.733
# 4                 27969004.68   27569311.41       399693.262
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 0                27858872.08  1.023010e+07      6864575.384       9047205.493
# 1                25994200.17  9.719067e+06      6438494.011       8309150.301
# ...

# %%
#IDENTIFICAR VALORES NULOS POR COLUMNA
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            6
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# electronicos_articulos_hogar            3
# ...

# %%
#IDENTIFICAR VALORES NULOS POR DATAFRAME
valores_nulos=df2.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(42)

# %%
#REALIZAMOS UNA COPIA DEL DATAFRAME
df3=df2.copy()

# %%
#PRIMER MÉTODO DE SUSUTITUCIÓN
#SUSTITUIR VALORES NULOS CON PROMEDIO O MEDIA
#Columna: salon_ventas -Método: Se sustituyen los valores nulos con el promedio (media).
df3["salon_ventas"]=df3["salon_ventas"].fillna(round(df2["salon_ventas"].mean(),1))

# %%
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# electronicos_articulos_hogar            3
# ...

# %%
#SEGUNDO MÉTODO DE SUSUTITUCIÓN
#sUSUTITUIR VALORES NULOS CON MEDIANA
#Columna: tarjetas_credito-Método: Se sustituyen los valores nulos con la mediana.

df3["tarjetas_credito"]=df3["tarjetas_credito"].fillna(round(df2["tarjetas_credito"].median(),1))

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        0
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# electronicos_articulos_hogar            3
# ...

# %%
#TERCER MÉTODO DE SUSTITUCIÓN
#SUSTITUIR VALORES NULOS POR UN VALOR NÚMERICO EN CONCRETO - SE UNA 
#Columna: almacen-Método: Se reemplazan valores nulos por 10 y podemos usar cualquuier número no solo el 10

df3["almacen"]=df3["almacen"].fillna(10)

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        0
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 0
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# electronicos_articulos_hogar            3
# ...

# %%
#CUARTO MÉTODO DE SUSUTITUCIÓN
#SUSTITUIR VALORES NULOS POR UN STRING EN CONCRETO
#Columna: subtotal_ventas_alimentos_bebidas-Método: Valores nulos son reemplazados por el string "21328882.9"
#yo use ese número del data 

df3["subtotal_ventas_alimentos_bebidas"]=df3["subtotal_ventas_alimentos_bebidas"].fillna("21328882.9")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        1
# tarjetas_credito                       0
# otros_medios                           1
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                0
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# otros                                  4
# ...

# %%
#QUINTO MÉTODO DE SUSUTITUCIÓN 
#SUSTITUIR VALORES NULOS POR VALORES NO NULOS HACIA ADELANTE "forward fill"
#FILTRO POR COLUMNAS
#Columnas: otros, tarjetas_debito, otros_medios, panaderia, lacteos, carnes, 
# verduleria_fruteria, alimentos_preparados_rotiseria, 
# indumentaria_calzado_textiles_hogar-Método: Los valores nulos son sustituidos por el último valor no nulo encontrado.
df3["otros"]=df3["otros"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\4290461345.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["otros"]=df3["otros"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        1
# tarjetas_credito                       0
# otros_medios                           1
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                0
# panaderia                              1
# lacteos                                1
# carnes                                 1
# ...

# %%
#SEXTO MÉTODO DE SUSUTITUCIÓN 
#SUSTITUIR VALORES NULOS POR VALORES NO NULOS HACIA ADELANTE "backward fill"
#FILTRO POR COLUMNAS
#Columnas: electronicos_articulos_hogar, bebidas-
# Método: Los valores nulos son sustituidos por el siguiente valor no nulo encontrado.
df3["electronicos_articulos_hogar"]=df3["electronicos_articulos_hogar"].fillna(method="bfill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\1028551076.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["electronicos_articulos_hogar"]=df3["electronicos_articulos_hogar"].fillna(method="bfill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        1
# tarjetas_credito                       0
# otros_medios                           1
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                0
# panaderia                              1
# lacteos                                1
# ...

# %%
df3["bebidas"]=df3["bebidas"].fillna(method="bfill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\238576617.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["bebidas"]=df3["bebidas"].fillna(method="bfill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        1
# tarjetas_credito                       0
# otros_medios                           1
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              1
# lacteos                                1
# carnes                                 1
# ...

# %%
df3["tarjetas_debito"]=df3["tarjetas_debito"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\2756945473.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["tarjetas_debito"]=df3["tarjetas_debito"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           1
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              1
# lacteos                                1
# ...

# %%
df3["otros_medios"]=df3["otros_medios"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\1759108328.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["otros_medios"]=df3["otros_medios"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              1
# lacteos                                1
# carnes                                 1
# ...

# %%
df3["panaderia"]=df3["panaderia"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\3489088569.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["panaderia"]=df3["panaderia"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                1
# carnes                                 1
# ...

# %%
df3["lacteos"]=df3["lacteos"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\2450673331.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["lacteos"]=df3["lacteos"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 1
# ...

# %%
df3["carnes"]=df3["carnes"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\3668298783.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["carnes"]=df3["carnes"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# ...

# %%
df3["verduleria_fruteria"]=df3["verduleria_fruteria"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\1005095467.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["verduleria_fruteria"]=df3["verduleria_fruteria"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# ...

# %%
df3["alimentos_preparados_rotiseria"]=df3["alimentos_preparados_rotiseria"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\1387344023.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["alimentos_preparados_rotiseria"]=df3["alimentos_preparados_rotiseria"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# ...

# %%
df3["indumentaria_calzado_textiles_hogar"]=df3["indumentaria_calzado_textiles_hogar"].fillna(method="ffill")

#Comprobamos valores nulos
valores_nulos=df3.isnull().sum()
valores_nulos
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3120\65980784.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3["indumentaria_calzado_textiles_hogar"]=df3["indumentaria_calzado_textiles_hogar"].fillna(method="ffill")
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# ...

# %%
#IDENTIFICAR VALORES NULOS POR COLUMNA
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            6
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# electronicos_articulos_hogar            3
# ...

# %%
#Copia de dataframe
df4=df2.copy()
df4
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                    45463.4
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                   177148.1                    24140.5
# 64                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07  2.759173e+07     2.671420e+05
# 1                 2.599420e+07  2.574918e+07     2.450208e+05
# 2                 2.778001e+07  2.747223e+07     3.077778e+05
# ...

# %%
df4=df2.dropna()
df4
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# 5                     29132.7                    26365.4
# 6                     31182.3                    27819.4
# 10                    33629.0                    28425.3
# 11                    40766.3                    34084.5
# 12                    32479.2                    26736.7
# 26                    51065.7                    24647.7
# 27                    49621.4                    23073.8
# 28                    50778.3                    22852.1
# 29                    54413.4                    23803.4
# 30                    55044.5                    23580.1
# ...

# %%
valores_nulos=df4.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# otros                                  0
# ...

# %%
#DATAFRAME (SUSUSTITUCIÓN)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ventas_precios_corrientes            65 non-null     float64
#  1   ventas_precios_constantes            65 non-null     float64
#  2   ventas_totales_canal_venta           65 non-null     float64
#  3   salon_ventas                         65 non-null     float64
#  4   canales_on_line                      65 non-null     float64
#  5   ventas_totales_medio_pago            65 non-null     float64
#  6   efectivo                             65 non-null     float64
#  7   tarjetas_debito                      65 non-null     float64
#  8   tarjetas_credito                     65 non-null     float64
#  9   otros_medios                         65 non-null     float64
#  10  ventas_totales_grupo_articulos       65 non-null     float64
# ...

# %%
#DATAFRAME4 ELIMINACIÓN
#(df4) fue creado eliminando completamente las filas que contenían valores nulos.
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 0 to 64
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ventas_precios_corrientes            39 non-null     float64
#  1   ventas_precios_constantes            39 non-null     float64
#  2   ventas_totales_canal_venta           39 non-null     float64
#  3   salon_ventas                         39 non-null     float64
#  4   canales_on_line                      39 non-null     float64
#  5   ventas_totales_medio_pago            39 non-null     float64
#  6   efectivo                             39 non-null     float64
#  7   tarjetas_debito                      39 non-null     float64
#  8   tarjetas_credito                     39 non-null     float64
#  9   otros_medios                         39 non-null     float64
#  10  ventas_totales_grupo_articulos       39 non-null     float64
# ...

# %%
#CONVERTIR DATASET SIN VALORES NULOS A CSV
df4.to_csv("Ventas_totales_sin_nulos.csv")
